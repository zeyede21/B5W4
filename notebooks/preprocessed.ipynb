# %%
import pandas as pd
# If the file is in the same directory
df = pd.read_csv('../data/tokenized_messages.csv')

# If it’s in a different directory, provide the relative or full path
# df = pd.read_csv('path/to/ner_sample.csv')
# Display first 5 rows
df.head(1000)
# Out:
#           channel                       date  views  \
# 0    ZemenExpress  2025-06-18 06:01:10+00:00   1995
# 1    ZemenExpress  2025-06-16 12:21:00+00:00   3086
# 2    ZemenExpress  2025-06-16 05:11:57+00:00   2612
# 3    ZemenExpress  2025-06-16 05:11:26+00:00   2397
# 4    ZemenExpress  2025-06-16 05:09:03+00:00   2592
# ..            ...                        ...    ...
# 995      sinayelj  2025-05-27 16:48:06+00:00   4926
# 996      sinayelj  2025-05-27 16:19:42+00:00   4659
# 997      sinayelj  2025-05-27 16:16:31+00:00   4714
# 998      sinayelj  2025-05-26 09:08:06+00:00   6369
# 999      sinayelj  2025-05-24 17:13:26+00:00   5156
#
#                                                   text  \
# 0    💥💥...................................💥💥\n\n📌Im...
# 1    💥💥...................................💥💥\n\n📌 B...
# 2    💥💥...................................💥💥\n\n📌Sm...
# 3    💥💥...................................💥💥\n\n📌Sm...
# 4    💥💥...................................💥💥\n\n📌**...
# ...
